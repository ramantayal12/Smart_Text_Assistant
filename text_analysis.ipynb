# %%
import nltk
import pandas as pd
import numpy as np

# %%
import pickle

# %% [markdown]
# ### importing train/test data

# %%
train_data = pd.read_csv('train_analysis_text.csv')
train_data.tail()
# Out:
#                                                     text  label
# 39995  "Western Union" is something of a forgotten cl...      1
# 39996  This movie is an incredible piece of work. It ...      1
# 39997  My wife and I watched this movie because we pl...      0
# 39998  When I first watched Flatliners, I was amazed....      1
# 39999  Why would this film be so good, but only gross...      1

# %% [markdown]
# ### cleaning data

# %%
category = train_data['label']
features = ('text')
x_train = train_data[features]

# %% [markdown]
# ### using count vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer as CV
from sklearn.feature_extraction.text import TfidfVectorizer as TFD
from sklearn.ensemble import RandomForestClassifier as RVC
from sklearn.model_selection import train_test_split as tts

# %%
cv = CV(min_df = 0.01,max_df = 0.9,ngram_range= (1,3))
x_train_features = cv.fit_transform(x_train)
x_test_features = cv.transform(x_test)
x_train_features
# Out:
# <40000x3788 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6033196 stored elements in Compressed Sparse Row format>

# %%
train_x,test_x,train_y,test_y = tts(x_train_features,category)

# %%
algo = RVC()
algo.fit(train_x,train_y)
algo.score(test_x,test_y)

# %%
from matplotlib import pyplot as pplot
x_axis = []
y_axis = []
for i in range(2,50):
    algo = RVC(max_depth = i)
    algo.fit(train_x,train_y)
    sc = algo.score(test_x,test_y)
    y_axis.append(sc)
    x_axis.append(i)

pplot.plot(x_axis,y_axis)

# %%
algo = RVC(max_depth=38)
algo.fit(x_train_features,category)
# Out:
# RandomForestClassifier(max_depth=38)

# %% [markdown]
# ### Exporting Model using pickle

# %%
filename = 'finalized_text_analysis_model.sav'
pickle.dump(algo, open(filename, 'wb'))

# %% [markdown]
# ### trying different algorithms for training

# %%
from sklearn.svm import SVC
algo2 = SVC()
algo2.fit(train_x,train_y)
algo2.score(test_x,test_y)
# Out:
# 0.7363445378151261

# %%
predictions = algo2.predict(x_test_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-df02a392090d> in <module>
# ----> 1 predictions = algo2.predict(x_test_features)
#       2 predictions
#
# /opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/svm/_base.py in predict(self, X)
#     613             y = np.argmax(self.decision_function(X), axis=1)
#     614         else:
# --> 615             y = super().predict(X)
#     616         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     617
#
# /opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/svm/_base.py in predict(self, X)
#     331         y_pred : ndarray of shape (n_samples,)
#     332         """
# --> 333         X = self._validate_for_predict(X)
#     334         predict = self._sparse_predict if self._sparse else self._dense_predict
#     335         return predict(X)
#
# /opt/anaconda3/envs/ml/lib/python3.7/site-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     484             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     485                              "the number of features at training time" %
# --> 486                              (X.shape[1], self.shape_fit_[1]))
#     487         return X
#     488
#
# ValueError: X.shape[1] = 3788 should be equal to 162, the number of features at training time

# %%
text_to_analyze = input()
text_to_analyze = cv.transform([text_to_analyze])
ans = algo.predict(text_to_analyze)
print(ans)
# Out:
# you are a good person
# [1]

# %%
np.savetxt(fname='preds.csv', X = predictions, fmt='%s')
ans = {
    'id' : test_data['id'],
    'target' : predictions
}
ans = pd.DataFrame(ans)
ans.to_csv('pred.csv',index = False)
